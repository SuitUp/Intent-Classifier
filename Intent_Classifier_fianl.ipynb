# %% [markdown]
# #Intent Classifier

# %%
#All the required imports.

import pandas as pd
import numpy as np
from io import StringIO
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
#Code for uploading the CSV file on Google Colab.
##when asked for please upload the 'TakeHome_task_data.csv' file here.

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-740c3c97-ba2b-4b3b-b723-f33f22686542" name="files[]" multiple disabled />
#      <output id="result-740c3c97-ba2b-4b3b-b723-f33f22686542">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TakeHome_task_data.csv to TakeHome_task_data (2).csv
# User uploaded file "TakeHome_task_data.csv" with length 181157 bytes

# %% [markdown]
# ##Data Preperation

# %% [markdown]
# ###Raw Data

# %%
#Reading the Dataset file

I_data = pd.read_csv('TakeHome_task_data.csv')

# %%
I_data.head(n =10)
# Out:
#                                                 data                 label
# 0  {'id': 'KG0OUA', 'data': 'Good morning', 'mess...              location
# 1  {'id': 'L9DC9H', 'data': 'Location', 'message_...             whoAreYou
# 2  {'id': 'ZQR6R5', 'data': 'hi', 'message_order'...             whoAreYou
# 3  {'id': 'RH0M4E', 'data': 'Hi', 'message_order'...              greeting
# 4  {'id': 'WLVX8I', 'data': 'Hello', 'message_ord...              greeting
# 5  {'id': 'M2IRWL', 'data': 'sir', 'message_order...             whoAreYou
# 6  {'id': '5MXRNL', 'data': 'K', 'message_order':...             whoAreYou
# 7  {'id': '609W8Y', 'data': 'On thanks', 'message...  dontMeetRequirements
# 8  {'id': 'T3V6IY', 'data': 'Hii', 'message_order...  dontMeetRequirements
# 9  {'id': 'GI07N1', 'data': 'Sir I dnt have two w...             whoAreYou

# %%
I_data.shape #gives tuple of 'rows x columns' for 'I_data' dataframe.
# Out:
# (2000, 2)

# %%
I_data.describe()
# Out:
#                                                      data      label
# count                                                2000       2000
# unique                                               2000          5
# top     {'id': 'MO79JO', 'data': 'but I have no bike',...  whoAreYou
# freq                                                    1        627

# %%
dataset = I_data

# %%
#Extracting Important Features from the given Dataset, that is TakeHome_task_data.csv

#creating a new feature 'id'! with all the values from the hash mapping.
dataset['id'] = dataset['data'].str.findall(r'id\': \'([A-Za-z0-9]+)\'').apply(np.squeeze)

#creating a new feature 'text'! with all the values from the hash mapping.
dataset['text'] = dataset['data'].str.findall(r'\'data\': \'(.+)\', \'message_order\'').apply(np.squeeze)
problem_indices = dataset[dataset['text'].apply(len) == 0].index.values
dataset.loc[problem_indices, 'text'] = dataset.loc[problem_indices, 'data'].str.findall(r'"(.+)"').apply(np.squeeze)

#creating a new feature 'message_order'! with all the values from the hash mapping.
dataset['message_order'] = dataset['data'].str.findall(r'\'message_order\': ([\d]+)').apply(np.squeeze)

#creating a new feature 'comments'! with all the values from the hash mapping.
dataset['comments'] = dataset['data'].str.findall(r'\'comments\': \[(.+)\]').apply(np.squeeze)

# %% [markdown]
# ###Processed Data

# %%
#a view at the new altered dataframe called 'dataset'!!

dataset.head(n=20)
# Out:
#                                                  data  ... comments
# 0   {'id': 'KG0OUA', 'data': 'Good morning', 'mess...  ...       ''
# 1   {'id': 'L9DC9H', 'data': 'Location', 'message_...  ...       ''
# 2   {'id': 'ZQR6R5', 'data': 'hi', 'message_order'...  ...       ''
# 3   {'id': 'RH0M4E', 'data': 'Hi', 'message_order'...  ...       ''
# 4   {'id': 'WLVX8I', 'data': 'Hello', 'message_ord...  ...       ''
# 5   {'id': 'M2IRWL', 'data': 'sir', 'message_order...  ...       ''
# 6   {'id': '5MXRNL', 'data': 'K', 'message_order':...  ...       ''
# 7   {'id': '609W8Y', 'data': 'On thanks', 'message...  ...       ''
# 8   {'id': 'T3V6IY', 'data': 'Hii', 'message_order...  ...       ''
# 9   {'id': 'GI07N1', 'data': 'Sir I dnt have two w...  ...       ''
# 10  {'id': 'GYJWFS', 'data': 'Hi', 'message_order'...  ...       ''
# 11  {'id': '6ZQLO7', 'data': 'Hlo', 'message_order...  ...       ''
# 12  {'id': '1XYSRQ', 'data': '📷 Good mrng', 'messa...  ...       ''
# 13  {'id': 'C7747X', 'data': 'Ok', 'message_order'...  ...       ''
# 14  {'id': 'WU1MHH', 'data': 'Gm', 'message_order'...  ...       ''
# 15  {'id': 'AL0YY2', 'data': 'Yes but no bikes sor...  ...       ''
# 16  {'id': 'NKB41P', 'data': 'Where it is', 'messa...  ...       ''
# 17  {'id': 'HKWKR6', 'data': 'Job placement compan...  ...       ''
# 18  {'id': 'OGBMAM', 'data': 'were', 'message_orde...  ...       ''
# 19  {'id': 'J7F5AP', 'data': 'Hiii', 'message_orde...  ...       ''
#
# [20 rows x 6 columns]

# %%
dataset.tail(n=10)
# Out:
#                                                    data  ... comments
# 1990  {'id': 'U0Z4ZF', 'data': 'Kk', 'message_order'...  ...       ''
# 1991  {'id': 'CK9IU9', 'data': 'Okay', 'message_orde...  ...       ''
# 1992  {'id': 'MDY1C7', 'data': 'Okay', 'message_orde...  ...       ''
# 1993  {'id': 'N7Z662', 'data': 'Where work', 'messag...  ...       ''
# 1994  {'id': 'O6TX8S', 'data': 'Mere paas khud ka na...  ...       ''
# 1995  {'id': '2RG46Y', 'data': 'OK by', 'message_ord...  ...       ''
# 1996  {'id': 'HCTZ3F', 'data': 'LL', 'message_order'...  ...       ''
# 1997  {'id': 'ITXTOW', 'data': 'Ok sir', 'message_or...  ...       ''
# 1998  {'id': 'IOKVYD', 'data': 'Hello', 'message_ord...  ...       ''
# 1999  {'id': 'UGBYIK', 'data': 'No bike', 'message_o...  ...       ''
#
# [10 rows x 6 columns]

# %% [markdown]
# ##Note:-
# ###The following features are not important for our model -
# ###1. 'id'
# all the values are unique and hence won't contribute towards our model's learning.
#
# ###2. 'message_order'
# couldn't really draw any conclusion over its importance in my classifier, and thus, din't use it.
#
# ###3. 'comments'
# all the values are the same over the entire dataset and thus render useless for our model's learning.

# %%
dataset.shape  ##gives tuple of 'rows x columns' for 'dataset' dataframe.
# Out:
# (2000, 6)

# %%
dataset.describe()
# Out:
#                                                      data  ... comments
# count                                                2000  ...     2000
# unique                                               2000  ...        1
# top     {'id': 'MO79JO', 'data': 'but I have no bike',...  ...       ''
# freq                                                    1  ...     2000
#
# [4 rows x 6 columns]

# %%
#Finding the unique values of Intent out of the given values.

intent = dataset['label']
unique_intent = set(intent)
list(unique_intent)
# Out:
# ['dontMeetRequirements', 'notInterested', 'location', 'whoAreYou', 'greeting']

# %%
sentences = dataset['text']
unique_sentences = sentences.unique()
print(len(unique_sentences))
list(unique_sentences)
# Out:
# 871
# ['Good morning',
#  'Location',
#  'hi',
#  'Hi',
#  'Hello',
#  'sir',
#  'K',
#  'On thanks',
#  'Hii',
#  'Sir I dnt have two wheeler',
#  'Hlo',
#  '\xf0\x9f\x93\xb7 Good mrng',
#  'Ok',
#  'Gm',
#  'Yes but no bikes sorry',
#  'Where it is',
#  'Job placement company',
#  'were',
#  'Hiii',
#  'No',
#  'Thank you',
#  'Where is the location?',
#  'Nahi',
#  'Marathi',
#  'Iska location kya hoga',
#  'Poda ...',
#  'Ldhu',
#  'I am not interested',
#  'How r u',
#  'Hi..',
#  'Hiio',
#  'Ok thanks \xf0\x9f\x99\x8f\xf0\x9f\x8f\xbb',
#  'Learning licence hai',
#  'Okkk',
#  'Bhaiii',
#  'Hey',
#  'Msg kyu karte hai',
#  'Hi sir',
#  'Hi ..',
#  'How are u',
#  'I have learning licence',
#  '\xf0\x9f\x93\xb7 G\xf0\x9f\x98\x8a\xf0\x9f\x98\x8aD Morning',
#  'okay',
#  'k',
#  "Don't msg",
#  'I have learning license',
#  'Lerner license only',
#  'OK bye dear t c good night',
#  'Thanks',
#  'Which location',
#  'ohhhh sry',
#  'Kidar hai job',
#  'Hallo',
#  'Area',
#  'I have LR licence',
#  'Hello Sir / Madam, sorry but I don\xe2\x80\x99t have bike \xf0\x9f\x8f\x8d',
#  'No one',
#  'Hy',
#  'Hai good morning',
#  "Hai I'm kishor",
#  'I applied',
#  'Y',
#  'Kkk',
#  'Where should I come',
#  'Ledu',
#  'I am interested in that job but no bike',
#  'Not interested',
#  'Already I have given dis answer before 3days back',
#  'Haa hai',
#  'inserted no',
#  'Helo',
#  'Hai',
#  'Two wheeler aahe',
#  'Kkkkk',
#  'Good Morning',
#  'Driving licence process',
#  'Location kya hai sir',
#  'Haii',
#  'hii',
#  'Ll',
#  'Sorry',
#  'Swiggy nai karna he merko',
#  'G sir',
#  'Kuthe aahe vacancey',
#  "Sry sir now I'm not interested on job",
#  'Okok',
#  'I have LLR',
#  'In which area',
#  'Location kon si rhe gi sir g',
#  'Where office',
#  'Hiiii',
#  'I have my learning license... Is it OK for job',
#  'Bt bike nhi aata',
#  "But I don't have two wheeler",
#  'Yas',
#  'Dear Sir or Mam',
#  'Llr',
#  'Hey mam',
#  "Sorry I didn't have original licence",
#  'I had already joined and left the job',
#  'Oky',
#  'Telugu Ni aati',
#  'Get lost',
#  'Near banashankari',
#  'I dnt have bike.\\n Will u provide??',
#  'Tq',
#  'Ohhh k\xf0\x9f\x98\x81\xf0\x9f\x98\x86\xf0\x9f\x98\x82\xf0\x9f\xa4\xa3',
#  'ok',
#  'Job location',
#  'Kahapar hai job',
#  'No we',
#  'Hlw',
#  "But i don't have a bike so have can i do this type of jobs",
#  'LLR license',
#  'K k',
#  'Ekada job',
#  'Driving license nai hai but gaadi hai',
#  '\xf0\x9f\x93\xb7 Gdmng',
#  'Sry I dnt have a bike to do this job.. Thank you',
#  'sir bike nahi hai',
#  'What location',
#  'I have a leaning license',
#  'Bhai',
#  'Okau',
#  'Helloooo',
#  'Good night',
#  'I want to my nearest Jalahalli Cross address',
#  'Hi unnati thx for contacting me ..',
#  'Ok ok',
#  'Where s the office',
#  'I applied for license but not yet received',
#  'how r u',
#  '\xe0\xa4\xac\xe0\xa4\xbe\xe0\xa4\x87\xe0\xa4\x95 \xe0\xa4\xa8\xe0\xa4\xb9\xe0\xa5\x80\xe0\xa4\x82 \xe0\xa4\xb9\xe0\xa5\x88',
#  '\xf0\x9f\x98\x85ok',
#  'Kk',
#  'you dont have swiggy offic in thane',
#  'Kahase vai',
#  'Where I have to come for interview',
#  'Hlo vahna',
#  'bike ledhu',
#  'Suno bhai Meri age nahi hai 17th hya',
#  'Okay',
#  'In which location',
#  'I have need job,but I am not apply fees',
#  'No licence',
#  'Bhi na bike hai na licence hai',
#  'I not interests',
#  'Sir..which area?',
#  'No bike',
#  'Why I should deposit???',
#  "But doesn't have driving license",
#  'Hello brother',
#  'hiii',
#  'K........tq so much sar or mam by',
#  'Okn',
#  'Hii sit',
#  'I dnt have bike but this job intrested',
#  'Why should i tell you',
#  'i have learning license',
#  'Sorry i m unable to pay 500 rupees',
#  'unexpectedly I applied for this job',
#  "don't send any text msg",
#  'Near vijaynagar?',
#  'Ur location',
#  'hello',
#  'But job location',
#  'Which city',
#  'You head office',
#  'Whr is your office pls',
#  'Gud mrng',
#  'Ok not interested',
#  "I have lost my license so I'm making new",
#  'OK.ok',
#  'Okey',
#  'Lr',
#  'Gud morning',
#  'Which area',
#  'But mere paas bike nhi hai',
#  'Hello job location akkada',
#  'Bhakk',
#  "I don't have vehicle sir",
#  'Location were',
#  'Wher',
#  'Dl',
#  'Snd the location',
#  'Two wheeler ahe pan license nahi',
#  'Hello me Peru',
#  'Interview place',
#  'Ok thanks sir',
#  'Job kaha pr h sir',
#  'Address',
#  'I have no bike',
#  'I have no two wheeler',
#  'yes but where are from',
#  'Hello how are you',
#  'Mere pass bike nhi hai',
#  'Hi ra',
#  '\xf0\x9f\x93\xb7 Good morning everyone.........',
#  '\xf0\x9f\x93\xb7 Good morning',
#  'Better i WL BLK u',
#  '\xe0\xa4\xae\xe0\xa5\x87\xe0\xa4\xb0\xe0\xa5\x87 \xe0\xa4\xaa\xe0\xa4\xbe\xe0\xa4\xb8 \xe0\xa4\xac\xe0\xa4\xbe\xe0\xa4\x87\xe0\xa4\x95 \xe0\xa4\xa8\xe0\xa4\xb9\xe0\xa5\x80 \xe0\xa4\xb9\xe0\xa5\x88',
#  'Where',
#  "I don't have vehicles and license also",
#  'Gd mrng',
#  'Am from thiruvallur where is job Location',
#  'Where is kasturinagar ?',
#  'Kidar hey',
#  '\xe0\xb0\xb2\xe0\xb1\x87\xe0\xb0\xa6\xe0\xb1\x81',
#  'Give address',
#  'learning licence',
#  'Dombivli mein hai kya??',
#  'Apply chesanu',
#  'Bat were',
#  'Bhai apka location kidar hi',
#  'IAM not interested',
#  'Hiii sir',
#  'Were is the place',
#  "I don't have bike",
#  'OK sir',
#  'I dot have licence',
#  'Learning license',
#  'Na Ku bike',
#  'Sir',
#  'Nhi karna h',
#  'Bike nhi hai',
#  "But I'm below 18",
#  'Mere paas filhaal driving licence ka paavti hai',
#  'Ol',
#  'Where!?',
#  'Gn',
#  'Whr in job',
#  'Kk thank you',
#  'Hold on',
#  'Where is office address',
#  'Ok sir',
#  "inshallah i we'll come",
#  'Bike Nahi hai.',
#  'I m under 18',
#  'Kk lev it',
#  'Where..?',
#  'Assalatu khairu minanum',
#  'Learning',
#  'Yes but i am no money',
#  'Sir can u say me were tht office',
#  'Ledhuu',
#  'Mere paas bike nhi hai',
#  'Sorry but muze bike chalana nhi aata',
#  'Where kasthuri nagar come',
#  'Ledhu,but teeeskuntanu',
#  'Halo',
#  'Im present busy',
#  'Sir I need job in near by rajajinagar, is there any delivery boy jobs',
#  'Where is the location',
#  'Okk',
#  'I have LL',
#  'Thanks for the information',
#  'Bro',
#  'Hi yari',
#  'Btw for which location',
#  'Licnc he but bike nahi',
#  'Noh',
#  'assalamualaikum',
#  'Office address',
#  '\xe0\xa4\x9c\xe0\xa4\xaf \xe0\xa4\xae\xe0\xa4\xb9\xe0\xa4\xbe\xe0\xa4\xb0\xe0\xa4\xbe\xe0\xa4\xb7\xe0\xa5\x8d\xe0\xa4\x9f\xe0\xa5\x8d\xe0\xa4\xb0',
#  "I don't hv bike and license",
#  'Ok thnx bro',
#  '4 welar lagana hy',
#  'thank u computer',
#  'I have my bicycle',
#  'Ledhu',
#  'But left ago 3months',
#  'I need clarity r else they will keep on calling and disturb',
#  'Gd night to all',
#  'Chal be',
#  'I dnt want in swiggy',
#  'Sir kamm kis state me ha',
#  'okkk',
#  'Licence hai',
#  'Which area and when',
#  '\xf0\x9f\x93\xb7 Good morning have a nice day \xf0\x9f\x91\x8d\xf0\x9f\x91\x8d\xf0\x9f\x98\x8e\xf0\x9f\x98\x8e',
#  'Sir job location kaha hai',
#  'Which is branch',
#  'learing i hve',
#  'Which place sir',
#  'Drop me the address',
#  'Whr is your office',
#  'Assalaamu alaikum',
#  'Kaha pr h',
#  'Not Sure',
#  'Sry i dnt have bike',
#  'Sorry l am not good ride vehicle.',
#  'no',
#  "I don't want job",
#  "Don't send this type of messages to me",
#  'Hello i have bike license but i Sold my bike can you arrange bike for me',
#  "Don't have interest",
#  'Which pleas',
#  'Hai...sir',
#  'How are you',
#  'No money to pay',
#  'Vasai Virar mein hai swiggy delivery boy vacancy',
#  'i dont have bike',
#  'LLR I have',
#  "But I don't have driving licence",
#  "I don't have a bike",
#  'Which area we will give',
#  'I have ll',
#  'Give office',
#  'Mere pass bike nahi',
#  'Where is the office',
#  'Hii good morning',
#  'Kon banega core pati ka contest hai kya',
#  'I have already done with this job',
#  'Nothing',
#  'Good afternoon',
#  'sry',
#  'I lose my DL',
#  '2apply',
#  'Gm Chill climate \xe2\x9d\x84\xe2\x98\x83',
#  'Ye kis jegha h',
#  "Salam where it's job",
#  'OK I understand',
#  'sorry',
#  'Bike ledhu',
#  'Thank you Unnati ..\\n Not now, may be later',
#  'Hai sir',
#  'Where will be tge work',
#  'Okya',
#  'Which place',
#  'Hyy',
#  'For which place you recruitment',
#  'Thanks for your concern.',
#  'Please pura address d',
#  'OK',
#  'O sorry no2',
#  'Thanks...',
#  'I dnt have bike and dl i knw ridng bike',
#  'Heyyyy',
#  'Oj',
#  'I have no bike .ie my problem.',
#  'Sorry not interested',
#  '\xf0\x9f\x98\xa6voke',
#  'Good m',
#  'I want online offline system other wise no chance then will be not interested',
#  'Thanks for your concern MR. Varun.',
#  "brother I don't hav bike and DL also ...",
#  'No thanks',
#  "You're making me angry seriously",
#  'Would u provide twowheller',
#  'Can you tell me the place of Office',
#  'Oki bro',
#  'Yes but i dont have license but i own a vehicle',
#  'I got job sir dnt txt me sry',
#  'Banane diya hi ...mere pass tha ...gum ho gaya hi',
#  'Learning license available',
#  'Bike nhi hu ga tu chil a gaa kya',
#  "Send me u r location.. i'll come there",
#  'Where?',
#  'Land mark?',
#  'Who are you to message me.Dont message me get lost first',
#  'LLr',
#  'No say',
#  'Lekin mere pass draving lision nahi hai',
#  'Which area bro',
#  'your location of branch',
#  'Bye',
#  'near by loction',
#  'gn',
#  'Kkkk',
#  'Mere pass paise nhi',
#  "Sir I had already worked here..\\n I don't need food delivery orders",
#  'M not interested for delivery jobs! Thank you',
#  "Ya\\n But i don't have license",
#  'I am not ready to deposit money',
#  'Just llr',
#  "I don't have bike insurance is it kk",
#  'Konsi jagah',
#  'Sorry I dont have bike . Thanks for u information',
#  'Where location',
#  'Where is it',
#  'Address 0lz',
#  'OK plz send me the above address',
#  'Hii bro',
#  'Kiddar',
#  'Sir i have no bike',
#  'Were',
#  'hi hello',
#  'You have opening in which city',
#  'But what will be the job location',
#  'Adras',
#  'Driving license',
#  'Kaha par hai job sar',
#  'bhai',
#  "Right now I don't have licence and bike",
#  'I dnt have bike right now when I ll get it i ll cum to you guys',
#  'Under process',
#  "Thanks for your services\\n I'm not interested for this job",
#  'Plzz stop it',
#  'Sorry nothing driver license',
#  'Thank you for your offer',
#  'Where are?',
#  'hy',
#  'Gud nyt',
#  'hi2',
#  'Can u share the address 1st',
#  "Thanks for u'r information",
#  'Sur good afternoon..',
#  'Hii sir',
#  "Swiggy don't need",
#  'Nice',
#  'Yeah',
#  'Ohk',
#  'I will refer one num so send this msg to him',
#  'Dont send fake',
#  'Hi bro',
#  'Thika muchkondu stop madu aste',
#  'Hi how are you',
#  'Thanks for ur support',
#  '1yes',
#  'Hello vahan',
#  "But don't vehicle in my castady",
#  'Haiii',
#  'Kormangala',
#  "I'm recently applied I have LR license.",
#  'Ok\xc4\xaf',
#  'But DL HAS GIVEN FOR RENEWAL',
#  'Only driving license',
#  'Hii si',
#  'No two viller iam very sorry',
#  'Nik siggu leda ra okasare chepthe',
#  'Mere bhai mujhe job nhi chahiye',
#  'Helloo',
#  'nonono',
#  'Location please',
#  'Sorry???',
#  'cheatinh',
#  'Hhi',
#  'Sry',
#  'Nonsense',
#  'Den go way',
#  "I don't have Lisence.. Can u manage to join as delivary boy",
#  'Acha',
#  'Good night....',
#  '2not now I will text u',
#  "I didn't DL I have LL",
#  'Ok k',
#  'How r you',
#  'Wer location job',
#  'Can I now location of job',
#  "I don't have bike or license",
#  'Or kaise hai',
#  'After 10 days am getting my LL',
#  '\xf0\x9f\x93\xb7 Good morning happy Friday \xf0\x9f\x92\xaa\xf0\x9f\x8f\xbb\xf0\x9f\x92\xaa\xf0\x9f\x8f\xbb\xf0\x9f\x91\x8d\xf0\x9f\x91\x8d',
#  'Lr undi',
#  "But I don't have buke",
#  'Oko',
#  'But i have llr',
#  '\xe0\xb0\xb6\xe0\xb1\x81\xe0\xb0\xad\xe0\xb1\x8b\xe0\xb0\xa6\xe0\xb0\xaf\xe0\xb0\x82',
#  'Naku bike ledu sar',
#  'Police complain karti hu ruk abhi',
#  'Hlo GM g',
#  "Don't send a msgs",
#  "I don't have a licensed",
#  'Where is ur office',
#  '1but I have an l l r',
#  'Location kha pr',
#  'ok sir',
#  'How are you???',
#  'Work location?',
#  'Work location',
#  'I nt have dl',
#  'okk',
#  'LL is there',
#  'Thanks foe ur information',
#  'sir. ok. but nodriveng. lince. no. pancaed',
#  'Plz didnot send me message plz stop I am not interested',
#  'Who',
#  'Thnaks bro',
#  'Tanq',
#  'If you are computer so I block you',
#  'which location in job',
#  'Sorry sir naku bike radu',
#  'License ny he',
#  'Good morning have a nice day',
#  'Hi good morning',
#  'But I have driving licence',
#  'Sorry I am not interested now.',
#  'where I should come',
#  'hi sir',
#  "I don't have license",
#  'Ya but. I have LLR',
#  'Im not interested in swiggy',
#  'I have learning license only',
#  'Na location change chesaru',
#  'Hello sollu pa',
#  "Thank you sir but I don't have a bike",
#  'License nahi hai',
#  'I want job but I have LR liasen',
#  'I do not have a bike license.',
#  "I don't have a bike not even driving licence",
#  "Yes sir.. I didn't D L n bike",
#  'Job location wr r u',
#  'Okh',
#  'Stop messaging',
#  'Great....Good night',
#  "He'll sar",
#  'Which location are their',
#  'Learners licence is available',
#  'Bro not interested',
#  "Sorry sir I don't have bike",
#  'Sir..\\n But I did not have pancard and bank account',
#  'Kelasa Elva',
#  'Good morning.....',
#  'Thank u',
#  'Abhi nhi phir kbhi',
#  'Tell me Job location',
#  'Okey sir',
#  'Kaha he job',
#  'Location??',
#  'Mai bike nai chalata hu',
#  'Hey will u just stop this',
#  'hlo',
#  'I have no vehicle',
#  'For this',
#  'No need thank you',
#  'Where is kasturi nager',
#  'Thanks for the info',
#  "I don't have bike and Dl Bro",
#  'Stopped',
#  'Kindly don text to this number',
#  'Hl',
#  'Mere pass bike or license nahi hr',
#  'I dont want to delivery jobs',
#  "But I can't pay Rs.500",
#  'Kaunsi si jagah job Milega',
#  'Baik nhi hai',
#  'I get licensee in 1month',
#  'Hello sir',
#  'Chal nikl',
#  'Location vasai hai',
#  'Hey hi',
#  'Present bike ledu tesukovali',
#  'Hi unnati',
#  'Which area sir',
#  'Acha ji',
#  'I am going to block you',
#  "Sir I don't need delivery jobs\\n That's it",
#  'Am not interested',
#  'Where job',
#  'Address kaha hai',
#  'Accha',
#  'hiiii',
#  'Driving licence nahi hey',
#  "Hello sir I don't have a bike but rest all documents i have it sir",
#  'Oka',
#  'I have learner license',
#  'Thank you ...',
#  'nko',
#  'I will no bike & dl',
#  'No . I say near r t nagar',
#  'I no redy',
#  'Job kha pila gi',
#  'Bike nahi hai',
#  'Where is u office',
#  'Area?',
#  'I dont have a pancard even',
#  'We accept llr license',
#  'Sir but mere pass bike aur licence nahi hai',
#  'Hie',
#  'Ya s but I have only LL no DL',
#  'Where is kasturi nagar',
#  "I don't have bike and license",
#  '\xf0\x9f\x91\xbe \xe0\xb2\xac\xe0\xb3\x86\xe0\xb2\xb3\xe0\xb2\x97\xe0\xb2\xbf\xe0\xb2\xa8 \xe0\xb2\xb6\xe0\xb3\x81\xe0\xb2\xad\xe0\xb3\x8b\xe0\xb2\xa6\xe0\xb2\xaf \xe0\xb2\x97\xe0\xb2\xb3\xe0\xb3\x81',
#  "Don't send am not interested",
#  'Oki',
#  "I dn't have a DL",
#  'Fine',
#  "Sir i don't know driving",
#  'job where are you',
#  "I don't have driving licence",
#  'Iam not interested in delivery job',
#  'where is the job location',
#  'Bt mere pas vehicle nh hai',
#  'K, fine',
#  'where are you from in job',
#  'bro Wr I should come',
#  'Thank you Sir',
#  'Morning',
#  'Soory i have no driving Lance',
#  "Yes im interested but don't have a two wheeler sir",
#  'I hv LL',
#  'Ok thaynku gd night jab par',
#  'Nahi dena mujhe',
#  'In which place',
#  'Job address location Mumbai pune',
#  'OK. Tq',
#  'Kidar apko milna hi',
#  'Merai pass bike nayi hai',
#  'Not both',
#  'Wokey',
#  'Wish',
#  'sir u r place Bangalore',
#  'Lening license',
#  'GOOD MORNING\xf0\x9f\x99\x8f\xf0\x9f\x8f\xbb\xf0\x9f\x99\x8f\xf0\x9f\x8f\xbb',
#  'Delivering location Chamrajpet Hanumantha Nagar Srinagar',
#  'I don\xe2\x80\x99t have bike',
#  'Learning is dhare',
#  'I can not write',
#  'LL',
#  'I have a no bike sir',
#  'Where the place',
#  'Bike nhi hai mere pass',
#  '1yes but present Learning Licence I am having',
#  'Hiii innappndra',
#  "But i won't have dl",
#  'Mere pass bike nahi hai',
#  'I dnt hav a bike',
#  'hi3',
#  'Jai Shree Ram',
#  'Hi hi hi',
#  'Were it is',
#  'But I am student for F.Y.B.com \\n I have no licence',
#  'Stop',
#  'LLR',
#  'Ook',
#  'I have only LLR license',
#  'Ok sure',
#  'Ha',
#  'Good morning sir',
#  'sry i dnt hav an bike',
#  "Both are too far I can't",
#  'Wear your office bro',
#  'LL is ther',
#  'Kaha par has job',
#  'Hi hi',
#  'Hi r',
#  'I have LLR next week lo licence vasthadi',
#  'Ur ofice adress',
#  'thankuuu',
#  'I dont have licience',
#  'No thanks..',
#  "Thank you sir but I don't have a bike.",
#  'Where is my location',
#  'Jus I have LLR',
#  'Interview kaha deni hogi',
#  'But sir mere pass baik nahi hai. Kya aap meri helf kar sakate hai...',
#  'BYKE is next month cmng',
#  'Where is your office',
#  'Learning licence',
#  'Good morning sir /madam',
#  'Par mere pass paise nahi he',
#  'Nahi he',
#  'Where job??',
#  '\xf0\x9f\x93\xb7 Photo',
#  'Hi I m not looking for',
#  '\xf0\x9f\x99\x84 Its in banagaluru ,right ?',
#  "sry mam in father's business",
#  'I dnt think so',
#  'Not interested thank you\xf0\x9f\x98\x8a',
#  'Kahhpe hy job amrvati',
#  'Wr is it ?',
#  'Sir I am intrasted. Bat I have not a baik. License is avalebal',
#  'Ok.',
#  "I'm back we're is your address plz tell me",
#  'Okkky',
#  'Gd evng..',
#  'This is for where sir...',
#  'I want to work bit no bike',
#  'muze bike chalani nHi ati',
#  'Prasent learning',
#  'Hi.. thanks for your message',
#  'May I know the location',
#  'Jai raam ki',
#  'Aur Area konsa',
#  'Send me Kurla office address',
#  'Mere pass bike nhi Hai',
#  'Rajajinagar',
#  'Actually having learners licence...need to apply for a drive test',
#  'I know your a software',
#  'Were am doing job?',
#  "Can't you understand what I said",
#  'kk',
#  'no other office',
#  'Give me address',
#  "Don't message it",
#  'Iam not interested in swiggy',
#  "But my license is yet to come.. It's gone Na work",
#  'Tq for your response',
#  'I have learning licence l vill get my license in 15 days',
#  '\xe0\xa4\x95\xe0\xa5\x81\xe0\xa4\x9f\xe0\xa5\x87 \xe0\xa4\xb9\xe0\xa5\x88',
#  'I am not Interested',
#  'Ha okl',
#  "If we don't have driving licence",
#  'Anna deposit Mado astu amount illa dayavittu nam bitbdi\xf0\x9f\x99\x8f',
#  'Job konsa state may hey',
#  'Hru',
#  'No le lo',
#  'Thnx to inform me',
#  'hi thank you for your sms',
#  'Which area?',
#  'Location sir',
#  'Ok thank you',
#  'Hi gm',
#  'Thank you for',
#  'Hi..Is there any vacancy in dilsuknagar..Part time',
#  'How are you?',
#  'Your office where in India',
#  'Learner licence',
#  'Sir mai delivery ka kaam nhi kar sakta',
#  'Which is nearest to yelahanka',
#  'But no bike no licence',
#  'Receipt hai learning',
#  'Sorry I Dnt have',
#  'Meanae thoo naa lagta madam\xf0\x9f\x98\x82',
#  'I dont have lisence i have only kearning license',
#  ', learning licence',
#  'Applications fee nai bhr skte',
#  'But mere pass bike nahi hai',
#  'Okk mam',
#  'Hi sir/madem',
#  'Tanks',
#  'Hi friend',
#  'Sorry me biji u',
#  'but I have no bike',
#  'Naku bike lisense ledhu bro',
#  'Sir dl no sir',
#  'K \xf0\x9f\x91\x8d\xf0\x9f\x8f\xbb thank u',
#  '\xe0\xa4\xa8\xe0\xa4\xae\xe0\xa4\xb8\xe0\xa5\x8d\xe0\xa4\x95\xe0\xa4\xbe\xe0\xa4\xb0',
#  'Please stay 1000 miles away from me ok',
#  'Shut up',
#  "Don't have bike",
#  'Llr apply',
#  'I have two wheeler',
#  'Hellooo',
#  '16 yrs old',
#  "No, it's too far",
#  '\xf0\x9f\x93\xb7 Good morning and have a blessed day',
#  'Wher is located',
#  'I have licence only',
#  'Thanks Sir',
#  'nhi chaiya',
#  "sry i can't come to ur place becoz it is from my place",
#  'Only LL now',
#  'Hai computer',
#  'Ok good night computer tomorrow Ok bye bye',
#  'Sir but licence nahi hai',
#  'Location ekkda',
#  'Kis jagah jab milega',
#  'Which city?',
#  'Sorry by mistake I type for delivery jobs',
#  'Where is kasthuri nagar',
#  'Kya location h',
#  'I wont give u money',
#  'Thanks sir',
#  'Time to batao',
#  'GD morning',
#  'I dnt hv bike',
#  'I have lerner licennce alredy apply for D/L soon it ll be dispatch',
#  'Location.',
#  'Nai kar naa hai',
#  'I dnt have a smart phone i have only learing licence',
#  'not interset',
#  "Don't send messages",
#  'No tks',
#  'Were is ur office',
#  'Hi thanks for considering my cv',
#  'I no message',
#  'Nooo',
#  'Helli',
#  "Sorry bye don't disturb",
#  'What areas bro',
#  'Hi sir and madam',
#  'Sir your mine office were',
#  'Which location is the job I will be working',
#  'So why did u msg me',
#  '2ella',
#  'I need job. I have learning license. I am possible this job',
#  'Not insert',
#  'I got a new bike but rc card innu bandilla..',
#  'Srryy',
#  'Aitu iru guru',
#  'Ye office kahan h',
#  'which location',
#  'Stupid',
#  "Hi sir I'm Suchindra",
#  'Sorry no bike',
#  'Not interested in delivery jobs',
#  'No sorry computer',
#  '2,4',
#  'But sir me paise nhi pay karunga',
#  '\xf0\x9f\x93\xb7 Good nyt',
#  'Licences. Bhi nahi hai',
#  'Location package',
#  'Where is koramangala....',
#  'I have llr',
#  "I like to kasturi nagar but on saturday I'm on amazon job",
#  'Kha ana hoga',
#  'K but my work location',
#  'Hi Unnati',
#  'Thank you for your valuable time sir',
#  'Jayanagar',
#  'Ok ok thn',
#  'Driveing license leadu',
#  'But I had no bike sir',
#  'abhi to nahi',
#  'did job isz in bnglr',
#  'Thanks for informing me',
#  'helo',
#  'Ledu maa Brother di Undi',
#  'Ok tell me',
#  'So',
#  'Tqq sir',
#  'Which airea located job',
#  'Dont have vehicle',
#  'hloo',
#  'Thnx',
#  'I have driving licences llr',
#  'Ledhu thechukunta',
#  "I don't have two wheeler license but own two wheeler so can I applied this Jo",
#  'Ok i think my mistake why am chat you\\n \\n And finally am block\\n \\n Sai ram!!!!',
#  'Where is interview',
#  "We don't have a interest",
#  'Mere paas bike nhi h',
#  'I vl block u',
#  'Edhi akada job',
#  'I have LR only',
#  'I have bike licence',
#  "But I don't have bike",
#  "Sorry I don't know to drive a 2wheeler bike ..",
#  'Ohhkk',
#  'Sir I want to know my working location',
#  'Hi....',
#  'L L',
#  'Learning I hv',
#  'Kidar He',
#  "I don't have Pan card",
#  'll chapu',
#  'Ya i have',
#  "When i don't know city name, how can I tell you",
#  '\xf0\x9f\x98\x89\xe2\x9c\x8c',
#  'Ok ji',
#  'Thanku lm not interested',
#  'Hindi nai aate',
#  'Sir mere pass gadi no',
#  'Not',
#  'Learning licence I have',
#  'Kaha pe job krna ho ga',
#  'Plz wait busy now n were location',
#  'Ohhh ok',
#  'Why you sent me message',
#  'Hy u',
#  'I have no bibek',
#  'Hieeee sir',
#  'Where are you office',
#  'But i dnt know reading',
#  'but sir i do not have a bikr',
#  'achha',
#  'Vahan delivery',
#  'Time nai hy mere pas',
#  'Then sry',
#  'Thank you sir',
#  'but...which city sir..actually i m belongs to nagpur',
#  'Sir I have no two wheeler',
#  'I blocked u',
#  'Thanks for this',
#  'Hay',
#  'Job whare',
#  "But I don't have license",
#  'Where work',
#  'Mere paas khud ka nai hai',
#  'OK by']

# %% [markdown]
# ##Building an Intent Classification Model

# %%
#write the 'dataset' dataframe to a CSV file for further use.
#note: it will be in the same file as the IPython notebook currently working on.

dataset.to_csv("Featured_data.csv")

# %%
#extract the data from the CSV file and will store it in the data frame.

def get_data():
    df = pd.read_csv("Featured_data.csv")
    return df

# %%
#we will prepare the data to feed it to the algorithm.

def data_prepare():
    col = ['label', 'text']
    
    #we get the complete data in ‘y’ and set the column for that data using y[col].
    y = get_data()
    y = y[col]
    
    #‘pd.notnull’ is being used for checking the data in the text column is null or not; if it’ s null the entire row is removed!
    y = y[pd.notnull(y['text'])]  #This step is important for getting the high quality clean data. Because, If we have good data we will have good results.
    y.columns = ['label', 'text']
    
    #We will make a new column ‘category_id’ which will give a number to classes. 
    #Example, say for greetings it will be 0, NotInterested 1 and so on.
    y['category_id'] = y['label'].factorize()[0]
    category_id_df = y[['label', 'category_id']].drop_duplicates().sort_values('category_id')  #removing duplicates.
    category_to_id = dict(category_id_df.values)
    id_to_category = dict(category_id_df[['category_id', 'label']].values)  #This will add the column in the dataframe.
    return y

# %% [markdown]
# ###Using ML technique: Naive Bayes

# %%
#I have used the 'Multinomial Naive_Bayes' algorithm for prediction because I find it easy to implement!
#Shorcoming: since the dataset given is 'limited' Naive_bayes approach does the job effectively.
            #but for large datasets, a deep learning model will produce the desired result.
#A short overview : Here, I have divided my data into test data and train data and then feed that data into the model.
def naive_algo():
    tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
    df = data_prepare()
    features = tfidf.fit_transform(df.text).toarray()
    labels = df.category_id
    features.shape
    X_train, X_test, y_train, y_test = train_test_split(df['text'], df['label'], random_state = 0)
    count_vect = CountVectorizer()
    X_train_counts = count_vect.fit_transform(X_train)
    tfidf_transformer = TfidfTransformer()
    X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
    clf = MultinomialNB().fit(X_train_tfidf, y_train)
    return clf, count_vect

# %%
#This function will give us the final prediction.

def predict(Input):
    clf, count_vect = naive_algo()
    intent = clf.predict(count_vect.transform([Input]))
    intent = str(intent).strip("['']")
    print(intent)
    return intent

# %% [markdown]
# ###Predictions

# %%
#At last, we enter the Input and pass it to the predict function.

test_input = raw_input("Enter your Input: ")  #raw_input for python2.
# Out:
# Enter your Input: who are you

# %%
x = predict(test_input)
# Out:
# greeting

# %%
intent = str(x).strip("['']")

# %%
print("The predicted Intent is: ")
print(intent)
# Out:
# The predicted Intent is:
# greeting

# %%
test_input_1 = raw_input("Try something different: ")
# Out:
# Try something different: kk

# %%
x_1 = predict(test_input_1)
# Out:
# notInterested

# %%
intent_1 = str(x_1).strip("['']")

# %%
print("The predicted Intent is: ")
print(intent_1)
# Out:
# The predicted Intent is:
# notInterested

# %% [markdown]
# #Insites of the model
#
# ###1.
# I have used the Multinomial Naive Bayes Classifier ( a simple ML algorithm for classification problem ) because of its easy implementation. And, also the given dataset in hand is relatively small to let one build a dense network model to compute preditions.
#
# ###2.
# There are warious data pre-processing methods to impact accuracy of the model, like, Tokenization, Stemming, Vectorization, etc. but to my evaluation they had no such significant impact on the model accuracy and behaviour.
#
# ###3.
# The multinomial naive bayes model applys the multi-label classification approach for the poblem. The OneVsRest strategy can be used for multi-label learning, where a classifier is used to predict multiple labels for instance. Naive Bayes supports multi-class, but I wanted a multi-label scenario, therefore, I wraped Naive Bayes in the OneVsRestClassifier.
#
# ####OneVsRest multi-label strategy
# The Multi-label algorithm accepts a binary mask over multiple labels. The result for each prediction will be an array of 0s and 1s marking which class labels apply to each row input sample.

# %% [markdown]
# ###Note:-
# I tried an approach of stemming the 'text' feature values, using 'LancesterStemmer' to better my data. But a quick reasearch made me to conclude that this has no significant ups on the model accuracy.

# %% [markdown]
# #References :-
#
# ###1. https://chatbotslife.com/know-your-intent-sota-results-in-intent-classification-8e1ca47f364c
#
# ###2. https://www.datacamp.com/community/tutorials/stemming-lemmatization-python
#
# ###3. https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html

# %% [markdown]
# #---------------------------------------------Thank You------------------------------------
